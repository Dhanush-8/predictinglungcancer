# %%
pip install bnlearn
# Out:
# Requirement already satisfied: bnlearn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.8.0)
# Requirement already satisfied: python-louvain in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (0.16)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (1.3.0)
# Requirement already satisfied: ipywidgets in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (8.0.6)
# Requirement already satisfied: networkx>=2.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (3.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (3.7.1)
# Requirement already satisfied: ismember in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (1.0.2)
# Requirement already satisfied: numpy>=1.24.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (1.24.3)
# Requirement already satisfied: packaging in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from bnlearn) (23.1)
# Requirement already satisfied: pandas==1.5.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (1.5.3)
# Requirement already satisfied: pypickle in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (1.1.0)
# Requirement already satisfied: statsmodels in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (0.14.0)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (2023.6.0)
# Requirement already satisfied: pgmpy>=0.1.18 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (0.1.23)
# Requirement already satisfied: funcsigs in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (1.0.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (4.65.0)
# Requirement already satisfied: df2onehot in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (1.0.6)
# Requirement already satisfied: tabulate in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (0.9.0)
# Requirement already satisfied: datazets in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bnlearn) (0.1.6)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas==1.5.3->bnlearn) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas==1.5.3->bnlearn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn) (10.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.3.4->bnlearn) (4.40.0)
# Requirement already satisfied: opt-einsum in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pgmpy>=0.1.18->bnlearn) (3.3.0)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pgmpy>=0.1.18->bnlearn) (1.3.1)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pgmpy>=0.1.18->bnlearn) (1.11.1)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pgmpy>=0.1.18->bnlearn) (2.0.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from datazets->bnlearn) (2.31.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipywidgets->bnlearn) (8.14.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipywidgets->bnlearn) (6.24.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipywidgets->bnlearn) (4.0.7)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipywidgets->bnlearn) (5.9.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipywidgets->bnlearn) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->bnlearn) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from statsmodels->bnlearn) (0.5.3)
# Requirement already satisfied: appnope in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (0.1.3)
# Requirement already satisfied: nest-asyncio in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (1.5.6)
# Requirement already satisfied: psutil in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (5.9.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (8.3.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (0.1.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (5.3.1)
# Requirement already satisfied: tornado>=6.1 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (6.3.2)
# Requirement already satisfied: pyzmq>=20 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (25.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (1.6.7)
# Requirement already satisfied: pygments>=2.4.0 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (2.15.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (3.0.38)
# Requirement already satisfied: pickleshare in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.7.5)
# Requirement already satisfied: stack-data in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.18.2)
# Requirement already satisfied: backcall in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.2.0)
# Requirement already satisfied: decorator in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (5.1.1)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels->bnlearn) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->datazets->bnlearn) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->datazets->bnlearn) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->datazets->bnlearn) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->datazets->bnlearn) (3.1.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->pgmpy>=0.1.18->bnlearn) (3.12.2)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->pgmpy>=0.1.18->bnlearn) (1.12)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->pgmpy>=0.1.18->bnlearn) (3.1.2)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->pgmpy>=0.1.18->bnlearn) (4.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->bnlearn) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->bnlearn) (3.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->bnlearn) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->bnlearn) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jinja2->torch->pgmpy>=0.1.18->bnlearn) (2.1.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->bnlearn) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->bnlearn) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->bnlearn) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy->torch->pgmpy>=0.1.18->bnlearn) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/saksh/Library/Python/3.10/lib/python/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import bnlearn as bn

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('train.csv').set_index('PassengerId')
test = pd.read_csv('test.csv').set_index('PassengerId')

# %%
train.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Dropping columns with many unique values
drop_list = ['Name', 'Age', 'Cabin', 'Ticket', 'Fare']
train = train.drop(columns=drop_list)
test = test.drop(columns=drop_list)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Embarked  889 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 48.7+ KB

# %%
# Data preparing
dfhot_train, dfnum_train = bn.df2onehot(train)
dfhot_test, dfnum_test = bn.df2onehot(test)
# Out:
# [df2onehot] >Auto detecting dtypes.
# 100%|██████████| 6/6 [00:00<00:00, 171.15it/s]
# [df2onehot] >Set dtypes in dataframe..
# [df2onehot]: 100%|██████████| 6/6 [00:00<00:00, 239.06it/s]
# [df2onehot] >Total onehot features: 18
#
# [df2onehot] >Auto detecting dtypes.
# 100%|██████████| 5/5 [00:00<00:00, 238.77it/s]
# [df2onehot] >Set dtypes in dataframe..
# [df2onehot]: 100%|██████████| 5/5 [00:00<00:00, 256.13it/s]
# [df2onehot] >Total onehot features: 14

# %%
dfnum_train
# Out:
#      Survived  Pclass  Sex  SibSp  Parch  Embarked
# 0           0       3    1      2      1         3
# 1           1       1    0      2      1         1
# 2           1       3    0      1      1         3
# 3           1       1    0      2      1         3
# 4           0       3    1      1      1         3
# ..        ...     ...  ...    ...    ...       ...
# 886         0       2    1      1      1         3
# 887         1       1    0      1      1         3
# 888         0       3    0      2      3         3
# 889         1       1    1      1      1         1
# 890         0       3    1      1      1         2
#
# [891 rows x 6 columns]

# %%
dfnum_target = dfnum_train.pop('Survived')

# %%
Xtrain, Xval, Ztrain, Zval = train_test_split(dfnum_train, dfnum_target, test_size=0.2, random_state=0)
valid = pd.concat([Xval, Zval], axis='columns')
dfnum = pd.concat([Xtrain, Ztrain], axis='columns')
dfnum
# Out:
#      Pclass  Sex  SibSp  Parch  Embarked  Survived
# 140       3    0      1      3         1         0
# 439       2    1      1      1         3         0
# 817       2    1      2      2         1         0
# 378       3    1      1      1         1         0
# 491       3    1      1      1         3         0
# ..      ...  ...    ...    ...       ...       ...
# 835       1    0      2      2         1         1
# 192       3    0      2      1         3         1
# 629       3    1      1      1         2         0
# 559       3    0      2      1         3         1
# 684       2    1      2      2         3         0
#
# [712 rows x 6 columns]

# %%
# Get score
def get_acc(model, df, col):
    # Get accuracy score by the model for the validation dataset df with target col
    pred = bn.predict(model, df, variables=[col])
    print(pred)
    acc = accuracy_score(df[col], pred[col])
    print('Accuracy -', acc)
    return acc

# %%
# %%time
# Structure learning
DAG = bn.structure_learning.fit(dfnum, methodtype='hc', root_node='Survived', bw_list_method='nodes', verbose=3)

# Plot
G = bn.plot(DAG)

# Parameter learning
model = bn.parameter_learning.fit(DAG, dfnum, verbose=3);
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of Pclass:
# +-----------+---------------------+---------------------+
# | Survived  | Survived(0)         | Survived(1)         |
# +-----------+---------------------+---------------------+
# | Pclass(1) | 0.2477813276535321  | 0.3501509271237602  |
# +-----------+---------------------+---------------------+
# | Pclass(2) | 0.2594959176428825  | 0.30487278999568784 |
# +-----------+---------------------+---------------------+
# | Pclass(3) | 0.49272275470358534 | 0.344976282880552   |
# +-----------+---------------------+---------------------+
# [bnlearn] >CPD of Embarked:
# +-------------+---------------------+-----+---------------------+
# | Pclass      | Pclass(1)           | ... | Pclass(3)           |
# +-------------+---------------------+-----+---------------------+
# | Embarked(0) | 0.16953642384105963 | ... | 0.11425959780621572 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(1) | 0.28874172185430463 | ... | 0.1855575868372943  |
# +-------------+---------------------+-----+---------------------+
# | Embarked(2) | 0.1675496688741722  | ... | 0.19652650822669104 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(3) | 0.3741721854304636  | ... | 0.5036563071297989  |
# +-------------+---------------------+-----+---------------------+
# [bnlearn] >CPD of Sex:
# +--------+---------------------+-----+--------------------+
# | Parch  | Parch(0)            | ... | Parch(3)           |
# +--------+---------------------+-----+--------------------+
# | Sex(0) | 0.5095057034220533  | ... | 0.5205047318611987 |
# +--------+---------------------+-----+--------------------+
# | Sex(1) | 0.49049429657794674 | ... | 0.4794952681388013 |
# +--------+---------------------+-----+--------------------+
# [bnlearn] >CPD of Survived:
# +-------------+--------------------+---------------------+
# | Sex         | Sex(0)             | Sex(1)              |
# +-------------+--------------------+---------------------+
# | Survived(0) | 0.4190093708165997 | 0.6487046632124353  |
# +-------------+--------------------+---------------------+
# | Survived(1) | 0.5809906291834003 | 0.35129533678756475 |
# +-------------+--------------------+---------------------+
# [bnlearn] >CPD of SibSp:
# +----------+----------+
# | SibSp(0) | 0.103777 |
# +----------+----------+
# | SibSp(1) | 0.381231 |
# +----------+----------+
# | SibSp(2) | 0.194899 |
# +----------+----------+
# | SibSp(3) | 0.111371 |
# +----------+----------+
# | SibSp(4) | 0.103193 |
# +----------+----------+
# | SibSp(5) | 0.10553  |
# +----------+----------+
# [bnlearn] >CPD of Parch:
# +----------+---------------------+-----+---------------------+
# | SibSp    | SibSp(0)            | ... | SibSp(5)            |
# +----------+---------------------+-----+---------------------+
# | Parch(0) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(1) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(2) | 0.23452157598499063 | ... | 0.26383763837638374 |
# +----------+---------------------+-----+---------------------+
# | Parch(3) | 0.2964352720450281  | ... | 0.27490774907749077 |
# +----------+---------------------+-----+---------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# CPU times: user 1.66 s, sys: 134 ms, total: 1.79 s
# Wall time: 667 ms

# %%
model
# Out:
# {'model': <pgmpy.models.BayesianNetwork.BayesianNetwork at 0x173201720>,
#  'adjmat': target    Pclass    Sex  SibSp  Parch  Embarked  Survived
#  source
#  Pclass     False  False  False  False      True     False
#  Sex        False  False  False  False     False      True
#  SibSp      False  False  False   True     False     False
#  Parch      False   True  False  False     False     False
#  Embarked   False  False  False  False     False     False
#  Survived    True  False  False  False     False     False,
#  'config': {'verbose': 3, 'method': 'bayes', 'n_jobs': -1},
#  'model_edges': [('Pclass', 'Embarked'),
#   ('Sex', 'Survived'),
#   ('Survived', 'Pclass'),
#   ('SibSp', 'Parch'),
#   ('Parch', 'Sex')],
#  'structure_scores': {'k2': -3176.1850309006445,
#   'bds': -3186.627937933029,
#   'bic': -3209.323591016363,
#   'bdeu': -3172.7649943218303},
#  'independence_test': None}

# %%
# Get score of the model1
acc1 = get_acc(model, valid, 'Survived')
# Out:
# [bnlearn]> Remaining columns for inference: 5
# 100%|██████████| 59/59 [00:00<00:00, 598.80it/s]
#      Survived         p
# 0           0  0.725084
# 1           0  0.725084
# 2           0  0.725084
# 3           1  0.662098
# 4           0  0.507407
# ..        ...       ...
# 174         0  0.507407
# 175         0  0.725084
# 176         1  0.662098
# 177         0  0.725084
# 178         0  0.725084
#
# [179 rows x 2 columns]
# Accuracy - 0.8156424581005587

# %%
# %%time
# Structure learning
DAG2 = bn.structure_learning.fit(dfnum, methodtype='hc', black_list=['SibSp'], root_node='Survived', bw_list_method='nodes', verbose=4)

# Plot
G2 = bn.plot(DAG2)

# Parameter learning
model2 = bn.parameter_learning.fit(DAG2, dfnum, verbose=4);
# Out:
# [bnlearn] >Filter variables (nodes) on black_list..
# [bnlearn] >Number of features after white/black listing: 5
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Removing columns from dataframe to make consistent with DAG [['SibSp']]
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of Pclass:
# +-----------+----------+
# | Pclass(1) | 0.294003 |
# +-----------+----------+
# | Pclass(2) | 0.279984 |
# +-----------+----------+
# | Pclass(3) | 0.426012 |
# +-----------+----------+
# [bnlearn] >CPD of Embarked:
# +-------------+---------------------+-----+---------------------+
# | Pclass      | Pclass(1)           | ... | Pclass(3)           |
# +-------------+---------------------+-----+---------------------+
# | Embarked(0) | 0.16953642384105963 | ... | 0.11425959780621572 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(1) | 0.28874172185430463 | ... | 0.1855575868372943  |
# +-------------+---------------------+-----+---------------------+
# | Embarked(2) | 0.1675496688741722  | ... | 0.19652650822669104 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(3) | 0.3741721854304636  | ... | 0.5036563071297989  |
# +-------------+---------------------+-----+---------------------+
# [bnlearn] >CPD of Survived:
# +-------------+--------------------+--------------------+--------------------+
# | Pclass      | Pclass(1)          | Pclass(2)          | Pclass(3)          |
# +-------------+--------------------+--------------------+--------------------+
# | Survived(0) | 0.4622516556291391 | 0.5083449235048678 | 0.6343692870201098 |
# +-------------+--------------------+--------------------+--------------------+
# | Survived(1) | 0.5377483443708609 | 0.4916550764951321 | 0.3656307129798903 |
# +-------------+--------------------+--------------------+--------------------+
# [bnlearn] >CPD of Sex:
# +----------+--------------------+--------------------+
# | Survived | Survived(0)        | Survived(1)        |
# +----------+--------------------+--------------------+
# | Sex(0)   | 0.3333333333333333 | 0.5614489003880984 |
# +----------+--------------------+--------------------+
# | Sex(1)   | 0.6666666666666666 | 0.4385510996119017 |
# +----------+--------------------+--------------------+
# [bnlearn] >CPD of Parch:
# +----------+---------------------+---------------------+
# | Sex      | Sex(0)              | Sex(1)              |
# +----------+---------------------+---------------------+
# | Parch(0) | 0.17938420348058903 | 0.13367875647668392 |
# +----------+---------------------+---------------------+
# | Parch(1) | 0.36947791164658633 | 0.5326424870466321  |
# +----------+---------------------+---------------------+
# | Parch(2) | 0.23025435073627845 | 0.17616580310880828 |
# +----------+---------------------+---------------------+
# | Parch(3) | 0.22088353413654618 | 0.15751295336787566 |
# +----------+---------------------+---------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# CPU times: user 880 ms, sys: 49.7 ms, total: 929 ms
# Wall time: 457 ms

# %%
# Score of the model2
acc2 = get_acc(model, valid.drop(columns=['SibSp']), 'Survived')
# Out:
# [bnlearn]> Remaining columns for inference: 4
# 100%|██████████| 34/34 [00:00<00:00, 711.73it/s]
#      Survived         p
# 0           0  0.725084
# 1           0  0.725084
# 2           0  0.725084
# 3           1  0.662098
# 4           0  0.507407
# ..        ...       ...
# 174         0  0.507407
# 175         0  0.725084
# 176         1  0.662098
# 177         0  0.725084
# 178         0  0.725084
#
# [179 rows x 2 columns]
# Accuracy - 0.8156424581005587

# %%
# Models comparing
res = bn.bnlearn.compare_networks(model, model2, figsize=(15, 8), verbose=3)
print('Coincidence -', (res[0][0, 0] + res[0][1, 1])/res[0].sum())
# Out:
# Coincidence - 0.76

# %%
# %%time
# Make inference
query = bn.inference.fit(model, variables=['Survived'], evidence={'Sex':True, 'Pclass':True})
print(query)
print(query.df)

# Another inference using only sex for evidence
q1 = bn.inference.fit(model, variables=['Survived'], evidence={'Sex':0})
print(query)
print(query.df)

# Print model
bn.print_CPD(model)
# Out:
# [bnlearn] >Variable Elimination..
# [bnlearn] >Data is stored in [query.df]
# +----+------------+----------+
# |    |   Survived |        p |
# +====+============+==========+
# |  0 |          0 | 0.566487 |
# +----+------------+----------+
# |  1 |          1 | 0.433513 |
# +----+------------+----------+
# +-------------+-----------------+
# | Survived    |   phi(Survived) |
# +=============+=================+
# | Survived(0) |          0.5665 |
# +-------------+-----------------+
# | Survived(1) |          0.4335 |
# +-------------+-----------------+
#    Survived         p
# 0         0  0.566487
# 1         1  0.433513
# [bnlearn] >Variable Elimination..
# [bnlearn] >Data is stored in [query.df]
# +----+------------+----------+
# |    |   Survived |        p |
# +====+============+==========+
# |  0 |          0 | 0.419009 |
# +----+------------+----------+
# |  1 |          1 | 0.580991 |
# +----+------------+----------+
# +-------------+-----------------+
# | Survived    |   phi(Survived) |
# +=============+=================+
# | Survived(0) |          0.5665 |
# +-------------+-----------------+
# | Survived(1) |          0.4335 |
# +-------------+-----------------+
#    Survived         p
# 0         0  0.566487
# 1         1  0.433513
# [bnlearn] >Data is stored in [query.df]
# +----+----------+------------+----------+
# |    |   Pclass |   Survived |        p |
# +====+==========+============+==========+
# |  0 |        1 |          0 | 0.247781 |
# +----+----------+------------+----------+
# |  1 |        1 |          1 | 0.350151 |
# +----+----------+------------+----------+
# |  2 |        2 |          0 | 0.259496 |
# +----+----------+------------+----------+
# |  3 |        2 |          1 | 0.304873 |
# +----+----------+------------+----------+
# |  4 |        3 |          0 | 0.492723 |
# +----+----------+------------+----------+
# |  5 |        3 |          1 | 0.344976 |
# +----+----------+------------+----------+
# CPD of Pclass:
# +-----------+---------------------+---------------------+
# | Survived  | Survived(0)         | Survived(1)         |
# +-----------+---------------------+---------------------+
# | Pclass(1) | 0.2477813276535321  | 0.3501509271237602  |
# +-----------+---------------------+---------------------+
# | Pclass(2) | 0.2594959176428825  | 0.30487278999568784 |
# +-----------+---------------------+---------------------+
# | Pclass(3) | 0.49272275470358534 | 0.344976282880552   |
# +-----------+---------------------+---------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+------------+----------+----------+
# |    |   Embarked |   Pclass |        p |
# +====+============+==========+==========+
# |  0 |          0 |        1 | 0.169536 |
# +----+------------+----------+----------+
# |  1 |          0 |        2 | 0.173853 |
# +----+------------+----------+----------+
# |  2 |          0 |        3 | 0.11426  |
# +----+------------+----------+----------+
# |  3 |          1 |        1 | 0.288742 |
# +----+------------+----------+----------+
# |  4 |          1 |        2 | 0.205146 |
# +----+------------+----------+----------+
# |  5 |          1 |        3 | 0.185558 |
# +----+------------+----------+----------+
# |  6 |          2 |        1 | 0.16755  |
# +----+------------+----------+----------+
# |  7 |          2 |        2 | 0.180111 |
# +----+------------+----------+----------+
# |  8 |          2 |        3 | 0.196527 |
# +----+------------+----------+----------+
# |  9 |          3 |        1 | 0.374172 |
# +----+------------+----------+----------+
# | 10 |          3 |        2 | 0.44089  |
# +----+------------+----------+----------+
# | 11 |          3 |        3 | 0.503656 |
# +----+------------+----------+----------+
# CPD of Embarked:
# +-------------+---------------------+-----+---------------------+
# | Pclass      | Pclass(1)           | ... | Pclass(3)           |
# +-------------+---------------------+-----+---------------------+
# | Embarked(0) | 0.16953642384105963 | ... | 0.11425959780621572 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(1) | 0.28874172185430463 | ... | 0.1855575868372943  |
# +-------------+---------------------+-----+---------------------+
# | Embarked(2) | 0.1675496688741722  | ... | 0.19652650822669104 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(3) | 0.3741721854304636  | ... | 0.5036563071297989  |
# +-------------+---------------------+-----+---------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+-------+---------+----------+
# |    |   Sex |   Parch |        p |
# +====+=======+=========+==========+
# |  0 |     0 |       0 | 0.509506 |
# +----+-------+---------+----------+
# |  1 |     0 |       1 | 0.349367 |
# +----+-------+---------+----------+
# |  2 |     0 |       2 | 0.502924 |
# +----+-------+---------+----------+
# |  3 |     0 |       3 | 0.520505 |
# +----+-------+---------+----------+
# |  4 |     1 |       0 | 0.490494 |
# +----+-------+---------+----------+
# |  5 |     1 |       1 | 0.650633 |
# +----+-------+---------+----------+
# |  6 |     1 |       2 | 0.497076 |
# +----+-------+---------+----------+
# |  7 |     1 |       3 | 0.479495 |
# +----+-------+---------+----------+
# CPD of Sex:
# +--------+---------------------+-----+--------------------+
# | Parch  | Parch(0)            | ... | Parch(3)           |
# +--------+---------------------+-----+--------------------+
# | Sex(0) | 0.5095057034220533  | ... | 0.5205047318611987 |
# +--------+---------------------+-----+--------------------+
# | Sex(1) | 0.49049429657794674 | ... | 0.4794952681388013 |
# +--------+---------------------+-----+--------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+------------+-------+----------+
# |    |   Survived |   Sex |        p |
# +====+============+=======+==========+
# |  0 |          0 |     0 | 0.419009 |
# +----+------------+-------+----------+
# |  1 |          0 |     1 | 0.648705 |
# +----+------------+-------+----------+
# |  2 |          1 |     0 | 0.580991 |
# +----+------------+-------+----------+
# |  3 |          1 |     1 | 0.351295 |
# +----+------------+-------+----------+
# CPD of Survived:
# +-------------+--------------------+---------------------+
# | Sex         | Sex(0)             | Sex(1)              |
# +-------------+--------------------+---------------------+
# | Survived(0) | 0.4190093708165997 | 0.6487046632124353  |
# +-------------+--------------------+---------------------+
# | Survived(1) | 0.5809906291834003 | 0.35129533678756475 |
# +-------------+--------------------+---------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+---------+----------+
# |    |   SibSp |        p |
# +====+=========+==========+
# |  0 |       0 | 0.103777 |
# +----+---------+----------+
# |  1 |       1 | 0.381231 |
# +----+---------+----------+
# |  2 |       2 | 0.194899 |
# +----+---------+----------+
# |  3 |       3 | 0.111371 |
# +----+---------+----------+
# |  4 |       4 | 0.103193 |
# +----+---------+----------+
# |  5 |       5 | 0.10553  |
# +----+---------+----------+
# CPD of SibSp:
# +----------+----------+
# | SibSp(0) | 0.103777 |
# +----------+----------+
# | SibSp(1) | 0.381231 |
# +----------+----------+
# | SibSp(2) | 0.194899 |
# +----------+----------+
# | SibSp(3) | 0.111371 |
# +----------+----------+
# | SibSp(4) | 0.103193 |
# +----------+----------+
# | SibSp(5) | 0.10553  |
# +----------+----------+
# [bnlearn] >Data is stored in [query.df]
# +----+---------+---------+----------+
# |    |   Parch |   SibSp |        p |
# +====+=========+=========+==========+
# |  0 |       0 |       0 | 0.234522 |
# +----+---------+---------+----------+
# |  1 |       0 |       1 | 0.066905 |
# +----+---------+---------+----------+
# |  2 |       0 |       2 | 0.154845 |
# +----+---------+---------+----------+
# |  3 |       0 |       3 | 0.223776 |
# +----+---------+---------+----------+
# |  4 |       0 |       4 | 0.235849 |
# +----+---------+---------+----------+
# |  5 |       0 |       5 | 0.230627 |
# +----+---------+---------+----------+
# |  6 |       1 |       0 | 0.234522 |
# +----+---------+---------+----------+
# |  7 |       1 |       1 | 0.722676 |
# +----+---------+---------+----------+
# |  8 |       1 |       2 | 0.412587 |
# +----+---------+---------+----------+
# |  9 |       1 |       3 | 0.291958 |
# +----+---------+---------+----------+
# | 10 |       1 |       4 | 0.235849 |
# +----+---------+---------+----------+
# | 11 |       1 |       5 | 0.230627 |
# +----+---------+---------+----------+
# | 12 |       2 |       0 | 0.234522 |
# +----+---------+---------+----------+
# | 13 |       2 |       1 | 0.109806 |
# +----+---------+---------+----------+
# | 14 |       2 |       2 | 0.253746 |
# +----+---------+---------+----------+
# | 15 |       2 |       3 | 0.25     |
# +----+---------+---------+----------+
# | 16 |       2 |       4 | 0.275472 |
# +----+---------+---------+----------+
# | 17 |       2 |       5 | 0.263838 |
# +----+---------+---------+----------+
# | 18 |       3 |       0 | 0.296435 |
# +----+---------+---------+----------+
# | 19 |       3 |       1 | 0.100613 |
# +----+---------+---------+----------+
# | 20 |       3 |       2 | 0.178821 |
# +----+---------+---------+----------+
# | 21 |       3 |       3 | 0.234266 |
# +----+---------+---------+----------+
# | 22 |       3 |       4 | 0.25283  |
# +----+---------+---------+----------+
# | 23 |       3 |       5 | 0.274908 |
# +----+---------+---------+----------+
# CPD of Parch:
# +----------+---------------------+-----+---------------------+
# | SibSp    | SibSp(0)            | ... | SibSp(5)            |
# +----------+---------------------+-----+---------------------+
# | Parch(0) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(1) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(2) | 0.23452157598499063 | ... | 0.26383763837638374 |
# +----------+---------------------+-----+---------------------+
# | Parch(3) | 0.2964352720450281  | ... | 0.27490774907749077 |
# +----------+---------------------+-----+---------------------+
# [bnlearn] >Independencies:
# (Survived ⟂ Embarked | Pclass)
# (Survived ⟂ SibSp | Parch)
# (Survived ⟂ Parch, SibSp | Sex)
# (Survived ⟂ SibSp, Embarked | Parch, Pclass)
# (Survived ⟂ Embarked | Pclass, SibSp)
# (Survived ⟂ Parch, SibSp, Embarked | Pclass, Sex)
# (Survived ⟂ SibSp | Parch, Embarked)
# (Survived ⟂ Parch, SibSp | Sex, Embarked)
# (Survived ⟂ SibSp | Parch, Sex)
# (Survived ⟂ Parch | SibSp, Sex)
# (Survived ⟂ SibSp | Parch, Pclass, Embarked)
# (Survived ⟂ Parch, SibSp | Pclass, Sex, Embarked)
# (Survived ⟂ Embarked | Parch, Pclass, SibSp)
# (Survived ⟂ SibSp, Embarked | Parch, Pclass, Sex)
# (Survived ⟂ Parch, Embarked | Pclass, SibSp, Sex)
# (Survived ⟂ SibSp | Parch, Sex, Embarked)
# (Survived ⟂ Parch | SibSp, Sex, Embarked)
# (Survived ⟂ SibSp | Parch, Pclass, Sex, Embarked)
# (Survived ⟂ Parch | Pclass, SibSp, Sex, Embarked)
# (Survived ⟂ Embarked | Parch, Pclass, SibSp, Sex)
# (Pclass ⟂ Parch, SibSp, Sex | Survived)
# (Pclass ⟂ SibSp | Parch)
# (Pclass ⟂ Parch, SibSp | Sex)
# (Pclass ⟂ Parch, SibSp, Sex | Survived, Embarked)
# (Pclass ⟂ SibSp, Sex | Parch, Survived)
# (Pclass ⟂ Parch, Sex | Survived, SibSp)
# (Pclass ⟂ Parch, SibSp | Survived, Sex)
# (Pclass ⟂ SibSp | Parch, Embarked)
# (Pclass ⟂ Parch, SibSp | Sex, Embarked)
# (Pclass ⟂ SibSp | Parch, Sex)
# (Pclass ⟂ Parch | SibSp, Sex)
# (Pclass ⟂ SibSp, Sex | Parch, Survived, Embarked)
# (Pclass ⟂ Parch, Sex | Survived, SibSp, Embarked)
# (Pclass ⟂ Parch, SibSp | Survived, Sex, Embarked)
# (Pclass ⟂ Sex | Parch, Survived, SibSp)
# (Pclass ⟂ SibSp | Parch, Survived, Sex)
# (Pclass ⟂ Parch | Survived, SibSp, Sex)
# (Pclass ⟂ SibSp | Parch, Sex, Embarked)
# (Pclass ⟂ Parch | SibSp, Sex, Embarked)
# (Pclass ⟂ Sex | Parch, Survived, SibSp, Embarked)
# (Pclass ⟂ SibSp | Parch, Survived, Sex, Embarked)
# (Pclass ⟂ Parch | Survived, SibSp, Sex, Embarked)
# (Embarked ⟂ Parch, SibSp, Sex | Survived)
# (Embarked ⟂ Parch, Survived, SibSp, Sex | Pclass)
# (Embarked ⟂ SibSp | Parch)
# (Embarked ⟂ Parch, SibSp | Sex)
# (Embarked ⟂ Parch, SibSp, Sex | Survived, Pclass)
# (Embarked ⟂ SibSp, Sex | Parch, Survived)
# (Embarked ⟂ Parch, Sex | Survived, SibSp)
# (Embarked ⟂ Parch, SibSp | Survived, Sex)
# (Embarked ⟂ Survived, SibSp, Sex | Parch, Pclass)
# (Embarked ⟂ Parch, Survived, Sex | Pclass, SibSp)
# (Embarked ⟂ Parch, Survived, SibSp | Pclass, Sex)
# (Embarked ⟂ SibSp | Parch, Sex)
# (Embarked ⟂ Parch | SibSp, Sex)
# (Embarked ⟂ SibSp, Sex | Parch, Survived, Pclass)
# (Embarked ⟂ Parch, Sex | Survived, SibSp, Pclass)
# (Embarked ⟂ Parch, SibSp | Survived, Sex, Pclass)
# (Embarked ⟂ Sex | Parch, Survived, SibSp)
# (Embarked ⟂ SibSp | Parch, Survived, Sex)
# (Embarked ⟂ Parch | Survived, SibSp, Sex)
# (Embarked ⟂ Survived, Sex | Parch, Pclass, SibSp)
# (Embarked ⟂ Survived, SibSp | Parch, Pclass, Sex)
# (Embarked ⟂ Parch, Survived | Pclass, SibSp, Sex)
# (Embarked ⟂ Sex | Parch, Survived, SibSp, Pclass)
# (Embarked ⟂ SibSp | Parch, Survived, Sex, Pclass)
# (Embarked ⟂ Parch | Survived, SibSp, Sex, Pclass)
# (Embarked ⟂ Survived | Parch, Pclass, SibSp, Sex)
# (Parch ⟂ Pclass, Embarked | Survived)
# (Parch ⟂ Embarked | Pclass)
# (Parch ⟂ Survived, Embarked, Pclass | Sex)
# (Parch ⟂ Embarked | Survived, Pclass)
# (Parch ⟂ Pclass | Survived, Embarked)
# (Parch ⟂ Pclass, Embarked | Survived, SibSp)
# (Parch ⟂ Pclass, Embarked | Survived, Sex)
# (Parch ⟂ Embarked | Pclass, SibSp)
# (Parch ⟂ Survived, Embarked | Pclass, Sex)
# (Parch ⟂ Survived, Pclass | Sex, Embarked)
# (Parch ⟂ Survived, Embarked, Pclass | SibSp, Sex)
# (Parch ⟂ Embarked | Survived, SibSp, Pclass)
# (Parch ⟂ Embarked | Survived, Sex, Pclass)
# (Parch ⟂ Pclass | Survived, SibSp, Embarked)
# (Parch ⟂ Pclass | Survived, Sex, Embarked)
# (Parch ⟂ Pclass, Embarked | Survived, SibSp, Sex)
# (Parch ⟂ Survived | Pclass, Sex, Embarked)
# (Parch ⟂ Survived, Embarked | Pclass, SibSp, Sex)
# (Parch ⟂ Survived, Pclass | SibSp, Sex, Embarked)
# (Parch ⟂ Embarked | Survived, SibSp, Sex, Pclass)
# (Parch ⟂ Pclass | Survived, SibSp, Sex, Embarked)
# (Parch ⟂ Survived | Pclass, SibSp, Sex, Embarked)
# (SibSp ⟂ Pclass, Embarked | Survived)
# (SibSp ⟂ Embarked | Pclass)
# (SibSp ⟂ Survived, Sex, Embarked, Pclass | Parch)
# (SibSp ⟂ Survived, Embarked, Pclass | Sex)
# (SibSp ⟂ Embarked | Survived, Pclass)
# (SibSp ⟂ Pclass | Survived, Embarked)
# (SibSp ⟂ Pclass, Sex, Embarked | Parch, Survived)
# (SibSp ⟂ Pclass, Embarked | Survived, Sex)
# (SibSp ⟂ Survived, Sex, Embarked | Parch, Pclass)
# (SibSp ⟂ Survived, Embarked | Pclass, Sex)
# (SibSp ⟂ Survived, Sex, Pclass | Parch, Embarked)
# (SibSp ⟂ Survived, Pclass | Sex, Embarked)
# (SibSp ⟂ Survived, Embarked, Pclass | Parch, Sex)
# (SibSp ⟂ Sex, Embarked | Parch, Survived, Pclass)
# (SibSp ⟂ Embarked | Survived, Sex, Pclass)
# (SibSp ⟂ Pclass, Sex | Parch, Survived, Embarked)
# (SibSp ⟂ Pclass | Survived, Sex, Embarked)
# (SibSp ⟂ Pclass, Embarked | Parch, Survived, Sex)
# (SibSp ⟂ Survived, Sex | Parch, Pclass, Embarked)
# (SibSp ⟂ Survived | Pclass, Sex, Embarked)
# (SibSp ⟂ Survived, Embarked | Parch, Pclass, Sex)
# (SibSp ⟂ Survived, Pclass | Parch, Sex, Embarked)
# (SibSp ⟂ Sex | Parch, Survived, Embarked, Pclass)
# (SibSp ⟂ Embarked | Parch, Survived, Sex, Pclass)
# (SibSp ⟂ Pclass | Parch, Survived, Sex, Embarked)
# (SibSp ⟂ Survived | Parch, Pclass, Sex, Embarked)
# (Sex ⟂ Pclass, Embarked | Survived)
# (Sex ⟂ Embarked | Pclass)
# (Sex ⟂ SibSp | Parch)
# (Sex ⟂ Embarked | Survived, Pclass)
# (Sex ⟂ Pclass | Survived, Embarked)
# (Sex ⟂ Pclass, SibSp, Embarked | Parch, Survived)
# (Sex ⟂ Pclass, Embarked | Survived, SibSp)
# (Sex ⟂ SibSp, Embarked | Parch, Pclass)
# (Sex ⟂ Embarked | Pclass, SibSp)
# (Sex ⟂ SibSp | Parch, Embarked)
# (Sex ⟂ SibSp, Embarked | Parch, Survived, Pclass)
# (Sex ⟂ Embarked | Survived, SibSp, Pclass)
# (Sex ⟂ Pclass, SibSp | Parch, Survived, Embarked)
# (Sex ⟂ Pclass | Survived, SibSp, Embarked)
# (Sex ⟂ Pclass, Embarked | Parch, Survived, SibSp)
# (Sex ⟂ SibSp | Parch, Pclass, Embarked)
# (Sex ⟂ Embarked | Parch, Pclass, SibSp)
# (Sex ⟂ SibSp | Parch, Survived, Embarked, Pclass)
# (Sex ⟂ Embarked | Parch, Survived, SibSp, Pclass)
# (Sex ⟂ Pclass | Parch, Survived, SibSp, Embarked)
# [bnlearn] >Nodes: ['Pclass', 'Embarked', 'Sex', 'Survived', 'SibSp', 'Parch']
# [bnlearn] >Edges: [('Pclass', 'Embarked'), ('Sex', 'Survived'), ('Survived', 'Pclass'), ('SibSp', 'Parch'), ('Parch', 'Sex')]
# CPU times: user 22.4 ms, sys: 4.27 ms, total: 26.7 ms
# Wall time: 25.3 ms
# {'Pclass':    Pclass  Survived         p
#  0       1         0  0.247781
#  1       1         1  0.350151
#  2       2         0  0.259496
#  3       2         1  0.304873
#  4       3         0  0.492723
#  5       3         1  0.344976,
#  'Embarked':     Embarked  Pclass         p
#  0          0       1  0.169536
#  1          0       2  0.173853
#  2          0       3  0.114260
#  3          1       1  0.288742
#  4          1       2  0.205146
#  5          1       3  0.185558
#  6          2       1  0.167550
#  7          2       2  0.180111
#  8          2       3  0.196527
#  9          3       1  0.374172
#  10         3       2  0.440890
#  11         3       3  0.503656,
#  'Sex':    Sex  Parch         p
#  0    0      0  0.509506
#  1    0      1  0.349367
#  2    0      2  0.502924
#  3    0      3  0.520505
#  4    1      0  0.490494
#  5    1      1  0.650633
#  6    1      2  0.497076
#  7    1      3  0.479495,
#  'Survived':    Survived  Sex         p
#  0         0    0  0.419009
#  1         0    1  0.648705
#  2         1    0  0.580991
#  3         1    1  0.351295,
#  'SibSp':    SibSp         p
#  0      0  0.103777
#  1      1  0.381231
#  2      2  0.194899
#  3      3  0.111371
#  4      4  0.103193
#  5      5  0.105530,
#  'Parch':     Parch  SibSp         p
#  0       0      0  0.234522
#  1       0      1  0.066905
#  2       0      2  0.154845
#  3       0      3  0.223776
#  4       0      4  0.235849
#  5       0      5  0.230627
#  6       1      0  0.234522
#  7       1      1  0.722676
#  8       1      2  0.412587
#  9       1      3  0.291958
#  10      1      4  0.235849
#  11      1      5  0.230627
#  12      2      0  0.234522
#  13      2      1  0.109806
#  14      2      2  0.253746
#  15      2      3  0.250000
#  16      2      4  0.275472
#  17      2      5  0.263838
#  18      3      0  0.296435
#  19      3      1  0.100613
#  20      3      2  0.178821
#  21      3      3  0.234266
#  22      3      4  0.252830
#  23      3      5  0.274908}

# %%
Pout = bn.predict(model, df=dfnum_test, variables=['Survived'])
Pout
# Out:
# [bnlearn]> Remaining columns for inference: 5
# 100%|██████████| 84/84 [00:00<00:00, 932.29it/s]
#      Survived         p
# 0           0  0.725084
# 1           0  0.507407
# 2           0  0.611161
# 3           0  0.725084
# 4           0  0.507407
# ..        ...       ...
# 413         0  0.725084
# 414         1  0.662098
# 415         0  0.725084
# 416         0  0.725084
# 417         0  0.725084
#
# [418 rows x 2 columns]

# %%
# Submission
submission = pd.read_csv('gender_submission.csv')
submission['Survived'] = Pout['Survived']
submission.to_csv('submission.csv', index=False)
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
